# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en drive
os.chdir("/content/gdrive/My Drive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ruta='/content/gdrive/MyDrive/Doctorado Tesis/Scripts/Climatologia/'
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# Lectura de data
U= pd.read_csv(ruta+'U_Canarias.csv',sep=',',parse_dates=['time'])
V= pd.read_csv(ruta+'V_Canarias.csv',sep=',',parse_dates=['time'])
P= pd.read_csv(ruta+'P_Canarias.csv',sep=',',parse_dates=['time'])
T= pd.read_csv(ruta+'T_Canarias.csv',sep=',',parse_dates=['time'])
Q= pd.read_csv(ruta+'Q_Canarias.csv',sep=',',parse_dates=['time'])
UO= pd.read_csv(ruta+'UO_Canarias.csv',sep=',',parse_dates=['time'])
VO= pd.read_csv(ruta+'VO_Canarias.csv',sep=',',parse_dates=['time'])
SST= pd.read_csv(ruta+'SST_Canarias.csv',sep=',',parse_dates=['time'])
S= pd.read_csv(ruta+'S_Canarias.csv',sep=',',parse_dates=['time'])
O= pd.read_csv(ruta+'O_Canarias.csv',sep=',',parse_dates=['time'])
CHL= pd.read_csv(ruta+'CHL_Canarias.csv',sep=',',parse_dates=['time'])
SSH= pd.read_csv(ruta+'SSH_Canarias.csv',sep=',',parse_dates=['time'])
Rotor= pd.read_csv(ruta+'Rotor_Canarias.csv',sep=',',parse_dates=['time'])
Estres= pd.read_csv(ruta+'Estres_Canarias.csv',sep=',',parse_dates=['time'])
MLD= pd.read_csv(ruta+'MLD_Canarias.csv',sep=',',parse_dates=['time'])

# %%
SST.head()
# Out:
#         time   Beddouzza  St Vincent       Blanc  Cabos Silleira        Juby
# 0 1993-01-01  290.009988  288.962486  291.229998      285.869989  290.519989
# 1 1993-01-02  289.969988  288.874982  290.619990      286.317506  289.404990
# 2 1993-01-03  289.734987  288.952496  290.547496      286.274995  289.417495
# 3 1993-01-04  289.552499  289.097491  290.502497      286.312493  289.382491
# 4 1993-01-05  289.507493  289.069988  290.397494      286.332497  289.387496

# %%
# Quitar la media de cada centro para analizar anomalias y ser ocomparable
U[list(U.columns[1:])]=U[list(U.columns[1:])] -U[list(U.columns[1:])].mean()
V[list(U.columns[1:])]=V[list(U.columns[1:])] -V[list(U.columns[1:])].mean()
P[list(U.columns[1:])]=P[list(U.columns[1:])] -P[list(U.columns[1:])].mean()
T[list(U.columns[1:])]=T[list(U.columns[1:])] -T[list(U.columns[1:])].mean()
Q[list(U.columns[1:])]=Q[list(U.columns[1:])] -Q[list(U.columns[1:])].mean()
UO[list(U.columns[1:])]=UO[list(U.columns[1:])] -UO[list(U.columns[1:])].mean()
VO[list(U.columns[1:])]=VO[list(U.columns[1:])] -VO[list(U.columns[1:])].mean()
SST[list(U.columns[1:])]=SST[list(U.columns[1:])] -SST[list(U.columns[1:])].mean()
S[list(U.columns[1:])]=S[list(U.columns[1:])] -S[list(U.columns[1:])].mean()
O[list(U.columns[1:])]=O[list(U.columns[1:])] -O[list(U.columns[1:])].mean()
CHL[list(U.columns[1:])]=CHL[list(U.columns[1:])] -CHL[list(U.columns[1:])].mean()
SSH[list(U.columns[1:])]=SSH[list(U.columns[1:])] -SSH[list(U.columns[1:])].mean()
Rotor[list(U.columns[1:])]=Rotor[list(U.columns[1:])] -Rotor[list(U.columns[1:])].mean()
Estres[list(U.columns[1:])]=Estres[list(U.columns[1:])] -Estres[list(U.columns[1:])].mean()
MLD[list(U.columns[1:])]=MLD[list(U.columns[1:])] -MLD[list(U.columns[1:])].mean()

# %%
U.head()
# Out:
#         time  Beddouzza  St Vincent     Blanc  Cabos Silleira      Juby
# 0 1993-01-01  -3.797729   -3.479891 -1.275300       -5.616311 -0.755505
# 1 1993-01-02  -2.313110   -1.420077 -0.502839       -3.808694  0.819690
# 2 1993-01-03  -1.055297   -1.229891 -4.185456        0.183494 -2.432995
# 3 1993-01-04  -3.452758   -1.039950 -5.455231        1.693259 -3.965466
# 4 1993-01-05  -2.595337   -5.904940 -1.625397        0.236228 -4.160534

# %%
# Grafica final 
w=1;h=0.07
import string
import matplotlib.cm  as cm
import matplotlib.dates as mdates
#colors = plt.cm.Paired(np.linspace(0, 1, 9))
#colors=['red','orange','green', 'purple', 'red','brown','pink','orangered','olive']
colors=['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#fdc086','#ffff99']
alpha=0.9
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
#fig,ax = plt.subplots(figsize=(18,10),nrows=5, ncols=3) # tamaño de figura
ax= plt.axes([0,1.5,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[0]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#NIño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#ax.axvspan(np.datetime64('2009-01-01T00:00:00.000000000'), np.datetime64('2010-01-01T00:00:00.000000000'), alpha=0.4, color='#882D17') #Moderate
#ax.axvspan(np.datetime64('2002-01-01T00:00:00.000000000'), np.datetime64('2003-01-01T00:00:00.000000000'), alpha=0.4, color='#882D17') #Moderate
#ax.axvspan(np.datetime64('1994-01-01T00:00:00.000000000'), np.datetime64('1995-01-01T00:00:00.000000000'), alpha=0.4, color='#882D17') #Moderate
#ax.axvspan(np.datetime64('2018-01-01T00:00:00.000000000'), np.datetime64('2019-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#ax.axvspan(np.datetime64('2014-01-01T00:00:00.000000000'), np.datetime64('2015-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#ax.axvspan(np.datetime64('2006-01-01T00:00:00.000000000'), np.datetime64('2007-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#ax.axvspan(np.datetime64('2004-01-01T00:00:00.000000000'), np.datetime64('2005-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
#ax.axvspan(np.datetime64('2011-01-01T00:00:00.000000000'), np.datetime64('2012-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Moderate
#ax.axvspan(np.datetime64('1995-01-01T00:00:00.000000000'), np.datetime64('1996-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Moderate
#ax.axvspan(np.datetime64('2016-01-01T00:00:00.000000000'), np.datetime64('2018-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
#ax.axvspan(np.datetime64('2005-01-01T00:00:00.000000000'), np.datetime64('2006-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
#ax.axvspan(np.datetime64('2008-01-01T00:00:00.000000000'), np.datetime64('2009-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
#ax.axvspan(np.datetime64('2000-01-01T00:00:00.000000000'), np.datetime64('2001-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
ax.plot(UO.time,UO['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(UO.time,UO['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(UO.time,UO['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(UO.time,UO['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(UO.time,UO['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.autoscale(enable=True, axis='x', tight=True)
ax.set_title('Zonal component currents (U)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.4,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[1]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[0,1].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(VO.time,VO['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(VO.time,VO['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(VO.time,VO['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(VO.time,VO['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(VO.time,VO['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Meridional component currents (V)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.3,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[2]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[0,2].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(SST.time,SST['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(SST.time,SST['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(SST.time,SST['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(SST.time,SST['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(SST.time,SST['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$°C$')
ax.set_title('Sea surface temperature', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.2,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[3]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[1,0].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(S.time,S['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(S.time,S['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(S.time,S['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(S.time,S['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(S.time,S['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$PSU$')
ax.set_title('Sea surface salinity', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.1,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[4]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(O.time,O['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(O.time,O['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(O.time,O['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(O.time,O['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(O.time,O['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$mmol m^{-3}$')
ax.set_title('Sea surface oxygen', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.0,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[5]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(CHL.time,CHL['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(CHL.time,CHL['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(CHL.time,CHL['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(CHL.time,CHL['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(CHL.time,CHL['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$mg m^{-3}$')
ax.set_title('Chlorophyll', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.9,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[6]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(SSH.time,SSH['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(SSH.time,SSH['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(SSH.time,SSH['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(SSH.time,SSH['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(SSH.time,SSH['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m$')
ax.set_title('Sea surface height', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.8,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[7]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Rotor.time,Rotor['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Rotor.time,Rotor['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Rotor.time,Rotor['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Rotor.time,Rotor['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(Rotor.time,Rotor['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$N m^{-3}$')
ax.set_title('Wind stress curl', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.7,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[8]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Estres.time,Estres['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Estres.time,Estres['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Estres.time,Estres['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Estres.time,Estres['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(Estres.time,Estres['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$N m^{-2}$')
ax.set_title('Wind stress', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.6,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[9]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(U.time,U['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(U.time,U['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(U.time,U['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(U.time,U['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(U.time,U['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Zonal component wind (U)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.5,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[10]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(V.time,V['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(V.time,V['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(V.time,V['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(V.time,V['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(V.time,V['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Meridional component wind (V)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.4,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[11]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(P.time,P['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(P.time,P['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(P.time,P['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(P.time,P['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(P.time,P['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$hPa$')
ax.set_title('Atmospheric Pressure', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.3,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[12]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(T.time,T['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(T.time,T['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(T.time,T['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(T.time,T['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(T.time,T['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$º C$')
ax.set_title('Air temperature', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.2,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[13]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Q.time,Q['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Q.time,Q['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Q.time,Q['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Q.time,Q['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(Q.time,Q['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$Wm^{-2}$')
ax.set_title('Shortwave radiation', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.1,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[14]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(MLD.time,MLD['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(MLD.time,MLD['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(MLD.time,MLD['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(MLD.time,MLD['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(MLD.time,MLD['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'm')
ax.set_title('Mixed Layer Depth', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax.legend(loc='lower center', bbox_to_anchor=(0.45, -0.55),ncol=9, fancybox=True, shadow=True,fontsize="x-large")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Grafica final 
w=1;h=0.07
import string
import matplotlib.cm  as cm
import matplotlib.dates as mdates
#colors = plt.cm.Paired(np.linspace(0, 1, 9))
#colors=['red','orange','green', 'purple', 'red','brown','pink','orangered','olive']
colors=['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#fdc086','#ffff99']
alpha=0.9
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
#fig,ax = plt.subplots(figsize=(18,10),nrows=5, ncols=3) # tamaño de figura
ax= plt.axes([0,1.5,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[0]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#NIño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong

ax.plot(UO.time,UO['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(UO.time,UO['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(UO.time,UO['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(UO.time,UO['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(UO.time,UO['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.autoscale(enable=True, axis='x', tight=True)
ax.set_title('Zonal component currents (U)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,1.4,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[1]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[0,1].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(VO.time,VO['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(VO.time,VO['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(VO.time,VO['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(VO.time,VO['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(VO.time,VO['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Meridional component currents (V)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,1.3,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[2]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[0,2].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(SST.time,SST['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(SST.time,SST['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(SST.time,SST['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(SST.time,SST['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(SST.time,SST['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$°C$')
ax.set_title('Sea surface temperature', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,1.2,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[3]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[1,0].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(S.time,S['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(S.time,S['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(S.time,S['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(S.time,S['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(S.time,S['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$PSU$')
ax.set_title('Sea surface salinity', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,1.1,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[4]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(O.time,O['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(O.time,O['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(O.time,O['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(O.time,O['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(O.time,O['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$mmol m^{-3}$')
ax.set_title('Sea surface oxygen', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,1.0,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[5]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(CHL.time,CHL['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(CHL.time,CHL['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(CHL.time,CHL['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(CHL.time,CHL['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(CHL.time,CHL['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$mg m^{-3}$')
ax.set_title('Chlorophyll', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.9,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[6]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(SSH.time,SSH['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(SSH.time,SSH['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(SSH.time,SSH['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(SSH.time,SSH['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(SSH.time,SSH['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m$')
ax.set_title('Sea surface height', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.8,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[7]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Rotor.time,Rotor['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Rotor.time,Rotor['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Rotor.time,Rotor['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Rotor.time,Rotor['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(Rotor.time,Rotor['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$N m^{-3}$')
ax.set_title('Wind stress curl', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.7,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[8]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Estres.time,Estres['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Estres.time,Estres['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Estres.time,Estres['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Estres.time,Estres['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(Estres.time,Estres['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$N m^{-2}$')
ax.set_title('Wind stress', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.6,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[9]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(U.time,U['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(U.time,U['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(U.time,U['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(U.time,U['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(U.time,U['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Zonal component wind (U)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.5,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[10]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(V.time,V['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(V.time,V['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(V.time,V['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(V.time,V['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(V.time,V['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Meridional component wind (V)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.4,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[11]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(P.time,P['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(P.time,P['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(P.time,P['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(P.time,P['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(P.time,P['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$hPa$')
ax.set_title('Atmospheric Pressure', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.3,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[12]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(T.time,T['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(T.time,T['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(T.time,T['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(T.time,T['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(T.time,T['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$º C$')
ax.set_title('Air temperature', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.2,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[13]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Q.time,Q['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Q.time,Q['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Q.time,Q['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Q.time,Q['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(Q.time,Q['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$Wm^{-2}$')
ax.set_title('Shortwave radiation', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
ax = plt.axes([0,0.1,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[14]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(MLD.time,MLD['Beddouzza'],c=colors[0],label='Beddouzza',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(MLD.time,MLD['St Vincent'],c=colors[1],label='St Vincent',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(MLD.time,MLD['Blanc'],c=colors[2],label='Blanc',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(MLD.time,MLD['Cabos Silleira'],c=colors[3],label='Cabos Silleira',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.plot(MLD.time,MLD['Juby'],c=colors[4],label='Juby',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'm')
ax.set_title('Mixed Layer Depth', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

# %%
# Tendencias
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
# Valores de x
def createList(r1, r2): 
    return [item for item in range(r1, r2+1)] 
# TENDENCIAS POR DECADA!!!!!!!!!!!!
# UO
print('-------------------- UO --------------------------')
r1, r2 = UO.index[0], UO.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(UO['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(UO['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(UO['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(UO['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(UO['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# VO
print('-------------------- VO --------------------------')
r1, r2 = VO.index[0], VO.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(VO['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(VO['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(VO['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(VO['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(VO['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
# SST
print('-------------------- SST --------------------------')
r1, r2 = SST.index[0], SST.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(SST['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SST['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(SST['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  
y = np.array(SST['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(SST['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
# SSS
print('-------------------- SSS --------------------------')
r1, r2 = S.index[0], S.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(S['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(S['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(S['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(S['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(S['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# O
print('-------------------- O --------------------------')
r1, r2 = O.index[0], O.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(O['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(O['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(O['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(O['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(O['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# CHL
print('-------------------- CHL --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(CHL['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(CHL['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(CHL['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(CHL['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(CHL['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# SSH
print('-------------------- SSH --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(SSH['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SSH['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SSH['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(SSH['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SSH['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# MLD
print('-------------------- MLD --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(MLD['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(MLD['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(MLD['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(MLD['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(MLD['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# Rotor
print('-------------------- Rotor --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(Rotor['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Rotor['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Rotor['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(Rotor['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Rotor['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
# Estres
print('-------------------- Estres --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(Estres['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Estres['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Estres['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(Estres['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Estres['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# U Wind
print('-------------------- U wind --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(U['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(U['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(U['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(U['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(U['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# V Wind
print('-------------------- V wind --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(V['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(V['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(V['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(V['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(V['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# P 
print('-------------------- P --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(P['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(P['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(P['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(P['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(P['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
# T 
print('-------------------- T --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(T['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(T['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(T['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(T['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(T['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# Q
print('-------------------- Q --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(Q['Beddouzza'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Beddouzza :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(Q['St Vincent'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 St Vincent :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(Q['Blanc'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Blanc :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  
y = np.array(Q['Cabos Silleira'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Cabos Silleira :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(Q['Juby'])
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Juby :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)
# Out:
# -------------------- UO --------------------------
# 1993-2019 Beddouzza : -0.004300419210585124  Error estandar: 0.0010386094931431609
# 1993-2019 St Vincent : -0.0010768887159787936  Error estandar: 0.0006231217205165578
# 1993-2019 Blanc : -0.000310966193632215  Error estandar: 0.0007523125738816502
# 1993-2019 Cabos Silleira : -0.0009181166453412421  Error estandar: 0.0006370121022379961
# 1993-2019 Juby : -0.0038930782962686224  Error estandar: 0.0011550603826981196
# -------------------- VO --------------------------
# 1993-2019 Beddouzza : -0.006792668610930021  Error estandar: 0.0016816717725687692
# 1993-2019 St Vincent : -0.005316405060418009  Error estandar: 0.0007932283440280928
# 1993-2019 Blanc : 0.010859452651301064  Error estandar: 0.001835231734877937
