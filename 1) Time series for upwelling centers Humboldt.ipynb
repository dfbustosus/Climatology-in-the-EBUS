# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en drive
os.chdir("/content/gdrive/My Drive")
# Out:
# Mounted at /content/gdrive

# %%
ruta='/content/gdrive/MyDrive/Doctorado Tesis/Scripts/Climatologia/'
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# Lectura de data
U= pd.read_csv(ruta+'U_Humboldt.csv',sep=',',parse_dates=['time'])
V= pd.read_csv(ruta+'V_Humboldt.csv',sep=',',parse_dates=['time'])
P= pd.read_csv(ruta+'P_Humboldt.csv',sep=',',parse_dates=['time'])
T= pd.read_csv(ruta+'T_Humboldt.csv',sep=',',parse_dates=['time'])
Q= pd.read_csv(ruta+'Q_Humboldt.csv',sep=',',parse_dates=['time'])
UO= pd.read_csv(ruta+'UO_Humboldt.csv',sep=',',parse_dates=['time'])
VO= pd.read_csv(ruta+'VO_Humboldt.csv',sep=',',parse_dates=['time'])
SST= pd.read_csv(ruta+'SST_Humboldt.csv',sep=',',parse_dates=['time'])
S= pd.read_csv(ruta+'S_Humboldt.csv',sep=',',parse_dates=['time'])
O= pd.read_csv(ruta+'O_Humboldt.csv',sep=',',parse_dates=['time'])
CHL= pd.read_csv(ruta+'CHL_Humboldt.csv',sep=',',parse_dates=['time'])
SSH= pd.read_csv(ruta+'SSH_Humboldt.csv',sep=',',parse_dates=['time'])
Rotor= pd.read_csv(ruta+'Rotor_Humboldt.csv',sep=',',parse_dates=['time'])
Estres= pd.read_csv(ruta+'Estres_Humboldt.csv',sep=',',parse_dates=['time'])

# %%
# Quitar la media de cada centro para analizar anomalias y ser ocomparable
U[list(U.columns[1:])]=U[list(U.columns[1:])] -U[list(U.columns[1:])].mean()
V[list(U.columns[1:])]=V[list(U.columns[1:])] -V[list(U.columns[1:])].mean()
P[list(U.columns[1:])]=P[list(U.columns[1:])] -P[list(U.columns[1:])].mean()
T[list(U.columns[1:])]=T[list(U.columns[1:])] -T[list(U.columns[1:])].mean()
Q[list(U.columns[1:])]=Q[list(U.columns[1:])] -Q[list(U.columns[1:])].mean()
UO[list(U.columns[1:])]=UO[list(U.columns[1:])] -UO[list(U.columns[1:])].mean()
VO[list(U.columns[1:])]=VO[list(U.columns[1:])] -VO[list(U.columns[1:])].mean()
SST[list(U.columns[1:])]=SST[list(U.columns[1:])] -SST[list(U.columns[1:])].mean()
S[list(U.columns[1:])]=S[list(U.columns[1:])] -S[list(U.columns[1:])].mean()
O[list(U.columns[1:])]=O[list(U.columns[1:])] -O[list(U.columns[1:])].mean()
CHL[list(U.columns[1:])]=CHL[list(U.columns[1:])] -CHL[list(U.columns[1:])].mean()
SSH[list(U.columns[1:])]=SSH[list(U.columns[1:])] -SSH[list(U.columns[1:])].mean()
Rotor[list(U.columns[1:])]=Rotor[list(U.columns[1:])] -Rotor[list(U.columns[1:])].mean()
Estres[list(U.columns[1:])]=Estres[list(U.columns[1:])] -Estres[list(U.columns[1:])].mean()

# %%
U.head()
# Out:
#         time  Coquimbo  Valparaiso  Concepcion  Mejillones
# 0 1993-01-01  1.302513    1.403669    1.856730    0.684085
# 1 1993-01-02  0.972434    1.346052    1.979044    1.636966
# 2 1993-01-03  1.287620    0.981306    1.576701    1.316898
# 3 1993-01-04  1.069847    0.923933    1.209025    1.309574
# 4 1993-01-05  1.462425    1.636335    1.741740    1.434574

# %%
VO.time
# Out:
# 0      1993-01-01
# 1      1993-01-02
# 2      1993-01-03
# 3      1993-01-04
# 4      1993-01-05
#           ...
# 9856   2019-12-27
# 9857   2019-12-28
# 9858   2019-12-29
# 9859   2019-12-30
# 9860   2019-12-31
# Name: time, Length: 9861, dtype: datetime64[ns]

# %%
# Grafica final 
w=1;h=0.07
import string
import matplotlib.cm  as cm
import matplotlib.dates as mdates
#colors = plt.cm.Paired(np.linspace(0, 1, 9))
#colors=['red','orange','green', 'purple', 'red','brown','pink','orangered','olive']
colors=['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#fdc086','#ffff99']
alpha=0.9
fig = plt.figure(figsize=(3.2*4.9,4.5*4.5))
#fig,ax = plt.subplots(figsize=(18,10),nrows=5, ncols=3) # tamaño de figura
ax= plt.axes([0,1.4,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[0]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#NIño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#ax.axvspan(np.datetime64('2009-01-01T00:00:00.000000000'), np.datetime64('2010-01-01T00:00:00.000000000'), alpha=0.4, color='#882D17') #Moderate
#ax.axvspan(np.datetime64('2002-01-01T00:00:00.000000000'), np.datetime64('2003-01-01T00:00:00.000000000'), alpha=0.4, color='#882D17') #Moderate
#ax.axvspan(np.datetime64('1994-01-01T00:00:00.000000000'), np.datetime64('1995-01-01T00:00:00.000000000'), alpha=0.4, color='#882D17') #Moderate
#ax.axvspan(np.datetime64('2018-01-01T00:00:00.000000000'), np.datetime64('2019-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#ax.axvspan(np.datetime64('2014-01-01T00:00:00.000000000'), np.datetime64('2015-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#ax.axvspan(np.datetime64('2006-01-01T00:00:00.000000000'), np.datetime64('2007-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#ax.axvspan(np.datetime64('2004-01-01T00:00:00.000000000'), np.datetime64('2005-01-01T00:00:00.000000000'), alpha=0.3, color='#882D17') #Weak
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
#ax.axvspan(np.datetime64('2011-01-01T00:00:00.000000000'), np.datetime64('2012-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Moderate
#ax.axvspan(np.datetime64('1995-01-01T00:00:00.000000000'), np.datetime64('1996-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Moderate
#ax.axvspan(np.datetime64('2016-01-01T00:00:00.000000000'), np.datetime64('2018-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
#ax.axvspan(np.datetime64('2005-01-01T00:00:00.000000000'), np.datetime64('2006-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
#ax.axvspan(np.datetime64('2008-01-01T00:00:00.000000000'), np.datetime64('2009-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
#ax.axvspan(np.datetime64('2000-01-01T00:00:00.000000000'), np.datetime64('2001-01-01T00:00:00.000000000'), alpha=0.4, color='#224C98') #Weak
ax.plot(UO.time,UO.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(UO.time,UO.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(UO.time,UO.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(UO.time,UO.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.autoscale(enable=True, axis='x', tight=True)
ax.set_title('Zonal component currents (U)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.3,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[1]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[0,1].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(VO.time,VO.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(VO.time,VO.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(VO.time,VO.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(VO.time,VO.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Meridional component currents (V)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.2,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[2]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[0,2].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(SST.time,SST.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(SST.time,SST.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(SST.time,SST.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(SST.time,SST.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$°C$')
ax.set_title('Sea surface temperature', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.1,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[3]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax[1,0].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(S.time,S.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(S.time,S.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(S.time,S.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(S.time,S.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$PSU$')
ax.set_title('Sea surface salinity', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,1.0,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[4]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax].legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(O.time,O.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(O.time,O.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(O.time,O.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(O.time,O.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$mmol m^{-3}$')
ax.set_title('Sea surface oxygen', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.9,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[5]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(CHL.time,CHL.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(CHL.time,CHL.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(CHL.time,CHL.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(CHL.time,CHL.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$mg m^{-3}$')
ax.set_title('Chlorophyll', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.8,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[6]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(SSH.time,SSH.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(SSH.time,SSH.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(SSH.time,SSH.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(SSH.time,SSH.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m$')
ax.set_title('Sea surface height', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.7,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[7]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Rotor.time,Rotor.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Rotor.time,Rotor.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Rotor.time,Rotor.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Rotor.time,Rotor.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$N m^{-3}$')
ax.set_title('Wind stress curl', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.6,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[8]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Estres.time,Estres.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Estres.time,Estres.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Estres.time,Estres.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Estres.time,Estres.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$N m^{-2}$')
ax.set_title('Wind stress', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.5,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[9]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(U.time,U.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(U.time,U.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(U.time,U.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(U.time,U.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Zonal component wind (U)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.4,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[10]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(V.time,V.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(V.time,V.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(V.time,V.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(V.time,V.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$m s^{-1}$')
ax.set_title('Meridional component wind (V)', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.3,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[11]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(P.time,P.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(P.time,P.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(P.time,P.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(P.time,P.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$hPa$')
ax.set_title('Atmospheric Pressure', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.2,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[12]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(T.time,T.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(T.time,T.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(T.time,T.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(T.time,T.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$º C$')
ax.set_title('Air temperature', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax = plt.axes([0,0.1,w,h])
ax.text(-0.07,1.01,string.ascii_lowercase[13]+')',fontsize=20, fontweight = 'bold', transform = ax.transAxes)
#ax.legend(ncol=9,fontsize='small',loc='upper center')
#Niño
ax.axvspan(np.datetime64('2015-01-01T00:00:00.000000000'), np.datetime64('2016-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very Strong
ax.axvspan(np.datetime64('1997-01-01T00:00:00.000000000'), np.datetime64('1998-01-01T00:00:00.000000000'), alpha=0.2, color='#882D17') #Very strong
#NIña
ax.axvspan(np.datetime64('2010-01-01T00:00:00.000000000'), np.datetime64('2011-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('2007-01-01T00:00:00.000000000'), np.datetime64('2008-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.axvspan(np.datetime64('1998-01-01T00:00:00.000000000'), np.datetime64('2000-01-01T00:00:00.000000000'), alpha=0.2, color='#224C98') #Very Strong
ax.plot(Q.time,Q.Coquimbo,c=colors[0],label='Coquimbo',linestyle='-',linewidth=0.5,alpha=alpha);ax.plot(Q.time,Q.Valparaiso,c=colors[1],label='Valparaiso',linestyle='--',linewidth=0.5,alpha=alpha);
ax.plot(Q.time,Q.Concepcion,c=colors[2],label='Concepcion',linestyle=':',linewidth=0.5,alpha=alpha);ax.plot(Q.time,Q.Mejillones,c=colors[3],label='Mejillones',linestyle='-.',linewidth=0.5,alpha=alpha);
ax.set_ylabel(r'$Wm^{-2}$')
ax.set_title('Shortwave radiation', fontweight='bold',fontsize=14)
ax.autoscale(enable=True, axis='x', tight=True);year = mdates.YearLocator(1,month=1,day=1)
year_fmt = mdates.DateFormatter('%Y');ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_fmt);ax.minorticks_off()

ax.legend(loc='lower center', bbox_to_anchor=(0.45, -0.55),ncol=9, fancybox=True, shadow=True,fontsize="x-large")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Tendencias
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
# Valores de x
def createList(r1, r2): 
    return [item for item in range(r1, r2+1)] 
# TENDENCIAS POR DECADA!!!!!!!!!!!!
# UO
print('-------------------- UO --------------------------')
r1, r2 = UO.index[0], UO.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(UO.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)
y = np.array(UO.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)
y = np.array(UO.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)
y = np.array(UO.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# VO
print('-------------------- VO --------------------------')
r1, r2 = VO.index[0], VO.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(VO.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(VO.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(VO.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(VO.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# SST
print('-------------------- SST --------------------------')
r1, r2 = SST.index[0], SST.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(SST.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SST.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SST.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(SST.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# SSS
print('-------------------- SSS --------------------------')
r1, r2 = S.index[0], S.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(S.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(S.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(S.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(S.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# O
print('-------------------- O --------------------------')
r1, r2 = O.index[0], O.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(O.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(O.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(O.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(O.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
# CHL
print('-------------------- CHL --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(CHL.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(CHL.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(CHL.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(CHL.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# SSH
print('-------------------- SSH --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(SSH.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SSH.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(SSH.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(SSH.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# Rotor
print('-------------------- Rotor --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(Rotor.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Rotor.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Rotor.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(Rotor.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# Estres
print('-------------------- Estres --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(Estres.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Estres.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(Estres.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(Estres.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# U Wind
print('-------------------- U wind --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(U.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(U.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(U.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(U.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# V Wind
print('-------------------- V wind --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(V.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(V.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(V.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(V.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# P 
print('-------------------- P --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(P.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(P.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(P.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(P.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# T 
print('-------------------- T --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(T.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(T.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
y = np.array(T.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(T.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) # Significativa
# Q
print('-------------------- Q --------------------------')
r1, r2 = CHL.index[0], CHL.index[-1]
x = np.array(createList(r1, r2)).reshape((-1, 1))
y = np.array(Q.Concepcion)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Concepcion :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(Q.Coquimbo)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Coquimbo :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10) 
y = np.array(Q.Mejillones)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Mejillones :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)  # Significativa
y = np.array(Q.Valparaiso)
results = sm.OLS(y,sm.add_constant(x)).fit()
print('1993-2019 Valparaiso :', results.params[1]*365*10, ' Error estandar:', results.bse[1]*365*10)
# Out:
# -------------------- UO --------------------------
# 1993-2019 Concepcion : 7.739987856534748e-05  Error estandar: 0.0005990361689272443
# 1993-2019 Coquimbo : -0.0002504905308128171  Error estandar: 0.0003570246734326402
# 1993-2019 Mejillones : -0.0002698843462283106  Error estandar: 0.00045835337749938884
# 1993-2019 Valparaiso : 0.0005173655765861261  Error estandar: 0.0004855716077403295
# -------------------- VO --------------------------
# 1993-2019 Concepcion : -0.007637954320613469  Error estandar: 0.0011258914750420929
# 1993-2019 Coquimbo : -0.0037372109440989352  Error estandar: 0.0010263872470650391
# 1993-2019 Mejillones : -0.004546493041904579  Error estandar: 0.0012028103831716033
# 1993-2019 Valparaiso : -0.005807271137900723  Error estandar: 0.0011137877328063017
# -------------------- SST --------------------------
# 1993-2019 Concepcion : -0.05488765984087765  Error estandar: 0.01594229903991079
# 1993-2019 Coquimbo : -0.09229113398529219  Error estandar: 0.021917346706197306
# 1993-2019 Mejillones : -0.02969138101268264  Error estandar: 0.028265208341167886
# 1993-2019 Valparaiso : -0.12213415549476819  Error estandar: 0.021786766444303884
# -------------------- SSS --------------------------
# 1993-2019 Concepcion : 0.016092539335288335  Error estandar: 0.010222123136012628
# 1993-2019 Coquimbo : -0.011699665385206368  Error estandar: 0.0011005674004578366
# 1993-2019 Mejillones : 0.008169308726570746  Error estandar: 0.002352307070982677
# 1993-2019 Valparaiso : -0.010732832197779575  Error estandar: 0.002562340131121197
# -------------------- O --------------------------
# 1993-2019 Concepcion : -0.7954225408442293  Error estandar: 0.5212412797103038
# 1993-2019 Coquimbo : 1.0709657310257423  Error estandar: 0.3797921059335674
# 1993-2019 Mejillones : -1.1618306068131972  Error estandar: 0.19508176549929462
